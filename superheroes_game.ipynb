# %%
import random

# %%
class superheroes():
    def __init__(self, name, superpowers):
        self.name = name
        self.superpowers = superpowers
        self.life_points = random.randint(4, 10)
    def attack(self):
        attack = random.randint(1, 10)
        return attack
    def decrease_life(self, x):
        self.life_points = self.life_points - x

# %%
rustman = superheroes('Rustman', ['airbone attack', 'lowkick', 'elbow smash'])
dustwoman = superheroes('Dust woman', ['sandstorm', 'sand wave', 'snake attack'])
iceworm = superheroes('Ice worm', ['icicle strike', 'blizzard', 'ice hug'])
fireghost = superheroes('Fire ghost', ['conflagration ', 'inferno', 'fireblast'])

# %%
heroes_list = [rustman, dustwoman, iceworm, fireghost]
counter =0

while len(heroes_list ) >1 :
    print("----round number-----", counter)
    fighters = random.sample(heroes_list , k=2)
    attack_list = []
    
    for fighter in fighters:
        attack_points = fighter.attack()
        attack_list.append(attack_points)
        superpower = random.choice(fighter.superpowers)
        print(f"Hero {fighter.name} with hp = {fighter.life_points}, fights with {superpower} and deals {attack_points}")
        
    if attack_list[0] > attack_list[1]:
        damage_delt = attack_list[0]-attack_list[1]
        fighters[1].decrease_life(ilosc_obrazen)
        print(f'Hero {fighters[0].name} wins with {fighters[1].name} dealing him {damage_delt} damage')
        
        if fighters[1].life_points <0:
            heroes_list.remove(fighters[1])
            print(f'Hero {fighters[1].name} dies')

    elif attack_list[1] > attack_list[0]:
        damage_delt = attack_list[1]-attack_list[0]
        fighters[0].decrease_life(damage_delt)
        print(f'Hero {fighters[1].name} wins with {fighters[0].name} dealing him {damage_delt} damage')
        
        if fighters[0].life_points <=0:
            heroes_list.remove(fighters[0])
            print(f'Hero {fighters[0].name} dies')
            
    else:
        
        print('DRAW')
        counter+=1
        continue
        
    ans = input()
    counter+=1


print("WINS : ", heroes_list[0].name)
# Out:
# ----round number----- 0
# Hero Fire ghost with hp = 8, fights with inferno and deals 4
# Hero Rustman with hp = 8, fights with airbone attack and deals 8
# Hero Rustman wins with Fire ghost dealing him 4 damage
#
# ----round number----- 1
# Hero Fire ghost with hp = 4, fights with fireblast and deals 5
# Hero Ice worm with hp = 4, fights with icicle strike and deals 10
# Hero Ice worm wins with Fire ghost dealing him 5 damage
# Hero Fire ghost dies
#
# ----round number----- 2
# Hero Dust woman with hp = 5, fights with sandstorm and deals 2
# Hero Rustman with hp = 8, fights with airbone attack and deals 4
# Hero Rustman wins with Dust woman dealing him 2 damage
#
# ----round number----- 3
# Hero Dust woman with hp = 3, fights with snake attack and deals 1
# Hero Ice worm with hp = 4, fights with icicle strike and deals 2
# Hero Ice worm wins with Dust woman dealing him 1 damage
#
# ----round number----- 4
# Hero Dust woman with hp = 2, fights with snake attack and deals 5
# ...
